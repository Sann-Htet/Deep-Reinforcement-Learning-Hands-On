# %%
import torch
from torch import nn

# %%
l = nn.Linear(2, 5)
v = torch.FloatTensor([1, 2])
l(v)
# Out:
# tensor([-0.8724,  0.6274,  0.7098, -0.0504,  1.1219], grad_fn=<ViewBackward0>)

# %%
s = nn.Sequential(
    nn.Linear(2, 5),
    nn.ReLU(),
    nn.Linear(5, 20),
    nn.ReLU(),
    nn.Linear(20, 10),
    nn.Dropout(p=0.3),
    nn.Softmax(dim=1)
)

# %%
s
# Out:
# Sequential(
#   (0): Linear(in_features=2, out_features=5, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=5, out_features=20, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=20, out_features=10, bias=True)
#   (5): Dropout(p=0.3, inplace=False)
#   (6): Softmax(dim=1)
# )

# %%
s(torch.FloatTensor([[1, 2]]))
# Out:
# tensor([[0.1108, 0.0883, 0.1108, 0.0979, 0.0654, 0.0836, 0.1108, 0.1108, 0.1108,
#          0.1108]], grad_fn=<SoftmaxBackward0>)
